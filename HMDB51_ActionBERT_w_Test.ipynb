# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py39" --user
# Out:
# --2022-11-13 13:54:41--  https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61451533 (59M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  58.60M  88.5MB/s    in 0.7s
#
# 2022-11-13 13:54:42 (88.5 MB/s) - ‘mini.sh’ saved [61451533/61451533]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - brotlipy==0.7.0=py39h27cfd23_1003
#     - ca-certificates==2020.12.8=h06a4308_0
#     - certifi==2020.12.5=py39h06a4308_0
#     - cffi==1.14.4=py39h261ae71_0
#     - chardet==3.0.4=py39h06a4308_1003
# ...

# %%
# !pip install opencv-python
# !pip install transformers 
# !pip install tensorboardX
# !pip install configs
# !pip install einops
# !pip install omegaconf
# !pip install hydra-core --upgrade
# !pip install torch
# !pip install torchvision
# !pip install opt_einsum
# !pip install pytorch_lightning
# !pip install rich
# !pip3 install -U scikit-learn scipy matplotlib
# !pip3 install torch torchvision torchaudio -f https://download.pytorch.org/whl/torch_stable.html
# !pip3 install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio==0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 60.9 MB 1.1 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 33.7 MB/s
# ...
#      |████████████████████████████████| 163 kB 84.3 MB/s
# ...
#      |████████████████████████████████| 661 kB 75.8 MB/s
# ...
#      |████████████████████████████████| 769 kB 100.3 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 102.3 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 26.8 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 71.3 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/apex
# Out:
# /content/apex

# %%
! git clone https://github.com/NVIDIA/apex
# %cd /content/apex
# !python3 setup.py install
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 10584, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 10584 (delta 58), reused 46 (delta 22), pack-reused 10477
# Receiving objects: 100% (10584/10584), 15.14 MiB | 7.46 MiB/s, done.
# Resolving deltas: 100% (7285/7285), done.
# /content/apex
#
#
# torch.__version__  = 1.8.1+cu111
#
#
# running install
# running bdist_egg
# running egg_info
# creating apex.egg-info
# writing apex.egg-info/PKG-INFO
# writing dependency_links to apex.egg-info/dependency_links.txt
# writing requirements to apex.egg-info/requires.txt
# writing top-level names to apex.egg-info/top_level.txt
# writing manifest file 'apex.egg-info/SOURCES.txt'
# reading manifest file 'apex.egg-info/SOURCES.txt'
# writing manifest file 'apex.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# ...

# %%
# !unrar x apex.rar
# %cd /content/apex
# !python3 setup.py install
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from apex.rar
#
# Creating    apex                                                      OK
#   OK
#   OK
#   OK
# Creating    apex/apex                                                 OK
# Creating    apex/apex/amp                                             OK
#   OK
#   OK
#   OK
#   OK
# Creating    apex/apex/amp/lists                                       OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    apex/apex/contrib                                         OK
# Creating    apex/apex/contrib/bottleneck                              OK
#   OK
#   OK
#   OK
#   OK
# Creating    apex/apex/contrib/clip_grad                               OK
#   OK
#   OK
# Creating    apex/apex/contrib/conv_bias_relu                          OK
#   OK
#   OK
# Creating    apex/apex/contrib/csrc                                    OK
# ...

# %%
# %cd /content
# Out:
# /content

# %%
! git clone https://github.com/MahiAh19/ModifiedActionBERTwS4.git
# Out:
# Cloning into 'ModifiedActionBERTwS4'...
# remote: Enumerating objects: 217, done.
# remote: Counting objects: 100% (217/217), done.
# remote: Compressing objects: 100% (199/199), done.
# remote: Total 217 (delta 21), reused 205 (delta 11), pack-reused 0
# Receiving objects: 100% (217/217), 345.16 KiB | 17.26 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# hollywood2 repo
#! git clone https://github.com/ming8924/Action-recognition.git
# Out:
# Cloning into 'Action-recognition'...
# remote: Enumerating objects: 852, done.
# remote: Total 852 (delta 0), reused 0 (delta 0), pack-reused 852
# Receiving objects: 100% (852/852), 16.22 MiB | 20.45 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
# %cd /content/test/
# Out:
# /content/test

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %cd /content/Action-recognition/data
# Out:
# /content/Action-recognition/data

# %%
# import numpy as np
# dataset = np.load('/content/video_test_0000004.npy', encoding='bytes')
# dataset.shape
# Out:
# (249, 2048)

# %%
# download hollywood2
# !wget ftp://ftp.irisa.fr/local/vistas/actions/Hollywood2-actions.tar.gz --no-check-certificate
# Out:
# --2022-11-13 14:06:55--  ftp://ftp.irisa.fr/local/vistas/actions/Hollywood2-actions.tar.gz
#            => ‘Hollywood2-actions.tar.gz’
# Resolving ftp.irisa.fr (ftp.irisa.fr)... 131.254.254.45, 2001:660:7303:254::45
# Connecting to ftp.irisa.fr (ftp.irisa.fr)|131.254.254.45|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /local/vistas/actions ... done.
# ==> SIZE Hollywood2-actions.tar.gz ... 16257179185
# ==> PASV ... done.    ==> RETR Hollywood2-actions.tar.gz ... done.
# Length: 16257179185 (15G) (unauthoritative)
#
# ons.tar.gz           60%[===========>        ]   9.23G  11.4MB/s    eta 7m 24s ^C

# %%
#extract hollywood2
# !sudo tar -xvf Hollywood2-actions.tar.gz
# Out:
# Hollywood2/AVIClips/
# Hollywood2/AVIClips/actioncliptest00001.avi
# Hollywood2/AVIClips/actioncliptest00002.avi
# Hollywood2/AVIClips/actioncliptest00003.avi
# Hollywood2/AVIClips/actioncliptest00004.avi
# Hollywood2/AVIClips/actioncliptest00005.avi
# Hollywood2/AVIClips/actioncliptest00006.avi
# Hollywood2/AVIClips/actioncliptest00007.avi
# Hollywood2/AVIClips/actioncliptest00008.avi
# Hollywood2/AVIClips/actioncliptest00009.avi
# Hollywood2/AVIClips/actioncliptest00010.avi
# Hollywood2/AVIClips/actioncliptest00011.avi
# Hollywood2/AVIClips/actioncliptest00012.avi
# Hollywood2/AVIClips/actioncliptest00013.avi
# Hollywood2/AVIClips/actioncliptest00014.avi
# Hollywood2/AVIClips/actioncliptest00015.avi
# Hollywood2/AVIClips/actioncliptest00016.avi
# Hollywood2/AVIClips/actioncliptest00017.avi
# Hollywood2/AVIClips/actioncliptest00018.avi
# Hollywood2/AVIClips/actioncliptest00019.avi
# Hollywood2/AVIClips/actioncliptest00020.avi
# Hollywood2/AVIClips/actioncliptest00021.avi
# ...

# %%
# download bounding box for hollywood2
! wget http://lear.inrialpes.fr/people/wang/download/bb_file.tar.gz --no-check-certificate
# Out:
# --2022-11-10 11:40:22--  http://lear.inrialpes.fr/people/wang/download/bb_file.tar.gz
# Resolving lear.inrialpes.fr (lear.inrialpes.fr)... 194.199.18.218
# Connecting to lear.inrialpes.fr (lear.inrialpes.fr)|194.199.18.218|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16379109 (16M) [application/x-gzip]
# Saving to: ‘bb_file.tar.gz’
#
# bb_file.tar.gz      100%[===================>]  15.62M  3.08MB/s    in 5.1s
#
# 2022-11-10 11:40:28 (3.08 MB/s) - ‘bb_file.tar.gz’ saved [16379109/16379109]

# %%
#extract bounding box
# !sudo tar -xvf bb_file.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# bb_file/UCF50/v_HighJump_g20_c04.bb
# bb_file/UCF50/v_HighJump_g20_c05.bb
# bb_file/UCF50/v_HighJump_g21_c01.bb
# bb_file/UCF50/v_HighJump_g21_c02.bb
# bb_file/UCF50/v_HighJump_g21_c03.bb
# bb_file/UCF50/v_HighJump_g21_c04.bb
# bb_file/UCF50/v_HighJump_g22_c01.bb
# bb_file/UCF50/v_HighJump_g22_c02.bb
# bb_file/UCF50/v_HighJump_g22_c03.bb
# bb_file/UCF50/v_HighJump_g22_c04.bb
# bb_file/UCF50/v_HighJump_g22_c05.bb
# bb_file/UCF50/v_HighJump_g23_c01.bb
# bb_file/UCF50/v_HighJump_g23_c02.bb
# bb_file/UCF50/v_HighJump_g23_c03.bb
# bb_file/UCF50/v_HighJump_g23_c04.bb
# bb_file/UCF50/v_HighJump_g23_c05.bb
# bb_file/UCF50/v_HighJump_g23_c06.bb
# bb_file/UCF50/v_HighJump_g24_c01.bb
# bb_file/UCF50/v_HighJump_g24_c02.bb
# bb_file/UCF50/v_HighJump_g24_c03.bb
# bb_file/UCF50/v_HighJump_g24_c04.bb
# bb_file/UCF50/v_HighJump_g24_c05.bb
# bb_file/UCF50/v_HighJump_g25_c01.bb
# bb_file/UCF50/v_HighJump_g25_c02.bb
# ...

# %% [markdown]
# # HMDB51

# %%
! wget http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar --no-check-certificate
# Out:
# --2022-11-13 14:20:46--  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Resolving serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)... 128.148.254.114
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar [following]
# --2022-11-13 14:20:47--  https://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2124008126 (2.0G)
# Saving to: ‘hmdb51_org.rar’
#
# hmdb51_org.rar      100%[===================>]   1.98G  12.3MB/s    in 2m 48s
#
# 2022-11-13 14:23:36 (12.0 MB/s) - ‘hmdb51_org.rar’ saved [2124008126/2124008126]

# %%
# make a new directory for hmdb51 extract it
# !mkdir hmdb51
# !mv /content/test/hmdb51_org.rar /content/test/hmdb51/
# %cd /content/test/hmdb51
# !unrar x hmdb51_org.rar
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from hmdb51_org.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
# unrar all the classes
# !unrar x brush_hair.rar
# !unrar x cartwheel.rar
# !unrar x catch.rar
# !unrar x chew.rar
# !unrar x clap.rar
# !unrar x climb.rar
# !unrar x climb_stairs.rar
# !unrar x dive.rar
# !unrar x draw_sword.rar
# !unrar x dribble.rar
# !unrar x drink.rar
# !unrar x eat.rar
# !unrar x fall_floor.rar
# !unrar x fencing.rar
# !unrar x flic_flac.rar
# !unrar x golf.rar
# !unrar x handstand.rar
# !unrar x hit.rar
# !unrar x hug.rar
# !unrar x jump.rar
# !unrar x kick.rar
# !unrar x kick_ball.rar
# !unrar x kiss.rar
# !unrar x laugh.rar
# !unrar x pick.rar
# !unrar x pour.rar
# !unrar x pullup.rar
# !unrar x punch.rar
# !unrar x push.rar
# !unrar x pushup.rar
# !unrar x ride_bike.rar
# !unrar x ride_horse.rar
# !unrar x run.rar
# !unrar x shake_hands.rar
# !unrar x shoot_ball.rar
# !unrar x shoot_bow.rar
# !unrar x shoot_gun.rar
# !unrar x sit.rar
# !unrar x situp.rar
# !unrar x smile.rar
# !unrar x smoke.rar
# !unrar x somersault.rar
# !unrar x stand.rar
# !unrar x swing_baseball.rar
# !unrar x sword.rar
# !unrar x sword_exercise.rar
# !unrar x talk.rar
# !unrar x throw.rar
# !unrar x turn.rar
# !unrar x walk.rar
# !unrar x wave.rar
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from hug.rar
#
# Creating    hug                                                       OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
#delete the .rar files
# !rm brush_hair.rar
# !rm cartwheel.rar
# !rm catch.rar
# !rm chew.rar
# !rm clap.rar
# !rm climb.rar
# !rm climb_stairs.rar
# !rm dive.rar
# !rm draw_sword.rar
# !rm dribble.rar
# !rm drink.rar
# !rm eat.rar
# !rm fall_floor.rar
# !rm fencing.rar
# !rm flic_flac.rar
# !rm golf.rar
# !rm handstand.rar
# !rm hit.rar
# !rm hug.rar
# !rm jump.rar
# !rm kick.rar
# !rm kick_ball.rar
# !rm kiss.rar
# !rm laugh.rar
# !rm pick.rar
# !rm pour.rar
# !rm pullup.rar
# !rm punch.rar
# !rm push.rar
# !rm pushup.rar
# !rm ride_bike.rar
# !rm ride_horse.rar
# !rm run.rar
# !rm shake_hands.rar
# !rm shoot_ball.rar
# !rm shoot_bow.rar
# !rm shoot_gun.rar
# !rm sit.rar
# !rm situp.rar
# !rm smile.rar
# !rm smoke.rar
# !rm somersault.rar
# !rm stand.rar
# !rm swing_baseball.rar
# !rm sword.rar
# !rm sword_exercise.rar
# !rm talk.rar
# !rm throw.rar
# !rm turn.rar
# !rm walk.rar
# !rm wave.rar

# !rm hmdb51_org.rar

# %%
# %cd /content
# Out:
# /content

# %%
# !pip install wandb -qU
# !wandb login
# Out:
#      |████████████████████████████████| 1.9 MB 30.3 MB/s
#      |████████████████████████████████| 96 kB 6.3 MB/s
#      |████████████████████████████████| 182 kB 112.1 MB/s
#      |████████████████████████████████| 63 kB 2.0 MB/s
#      |████████████████████████████████| 166 kB 85.9 MB/s
#      |████████████████████████████████| 140 kB 98.0 MB/s
# ...
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
! python3 /content/test/prepare_hmdb51.py \
-v /content/test/hmdb51\
-o /content/test/testFrame\
-s 0.8 -fps 1
# Out:
# Train, Validation and Test sets saved in:
# /content/test/testFrame/train_ucf101.json
# /content/test/testFrame/val_ucf101.json
# /content/test/testFrame/test_ucf101.json
#
# 0 / 6766
# 1000 / 6766
# 2000 / 6766
# 3000 / 6766
# 4000 / 6766
# 5000 / 6766
# 6000 / 6766
# Done! Video Frames saved in /content/test/testFrame/frames_fps_1

# %%
! python3 /content/test/prepare_data.py -s test \
-f /content/test/testFrame/frames_fps_1\
-j /content/test/testFrame/test_ucf101.json \
-o /content/test/testFrame/data_res18_fps_1 \
-m resnet18 -bs 1024 -nw 4
# Out:
# Selected Device: cuda:0
# 6766
# Total Videos: 722  |  Total Frames: 2032  |  Max Video length: 37
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# 100% 44.7M/44.7M [00:00<00:00, 246MB/s]
# Processed json saved at /content/test/testFrame/data_res18_fps_1/test.json
# Embeddings: 100% 2/2 [00:06<00:00,  3.19s/it]
# The embeddings memmap file saved at /content/test/testFrame/data_res18_fps_1/test.npy
# Total execution time 10.82 secs

# %%
! python3 /content/test/prepare_data.py -s train \
-f /content/test/testFrame/frames_fps_1\
-j /content/test/testFrame/train_ucf101.json \
-o /content/test/testFrame/data_res18_fps_1 \
-m resnet18 -bs 1024 -nw 4
# Out:
# Selected Device: cuda:0
# 6766
# Total Videos: 5390  |  Total Frames: 14786  |  Max Video length: 37
# Processed json saved at /content/test/testFrame/data_res18_fps_1/train.json
# Embeddings: 100% 15/15 [00:22<00:00,  1.52s/it]
# The embeddings memmap file saved at /content/test/testFrame/data_res18_fps_1/train.npy
# Total execution time 27.53 secs

# %%
! python3 /content/test/prepare_data.py -s val \
-f /content/test/testFrame/frames_fps_1\
-j /content/test/testFrame/val_ucf101.json \
-o /content/test/testFrame/data_res18_fps_1 \
-m resnet18 -bs 1024 -nw 4
# Out:
# Selected Device: cuda:0
# 6766
# Total Videos: 654  |  Total Frames: 1732  |  Max Video length: 37
# Processed json saved at /content/test/testFrame/data_res18_fps_1/val.json
# Embeddings: 100% 2/2 [00:06<00:00,  3.04s/it]
# The embeddings memmap file saved at /content/test/testFrame/data_res18_fps_1/val.npy
# Total execution time 10.25 secs

# %%
#Transformer train + val + test
! python3 /content/test/main.py --mode test --expt_dir ./results_log  \
--expt_name BERT --model bert \
--data_dir /content/test/testFrame/data_res18_fps_1 \
--run_name res18_1fps_lyr_2_bs_256_lr_1e4 \
--num_layers 5 --batch_size 256 --epochs 300 \
--gpu_id 0 --opt_lvl 1  --num_workers 4 --lr 1e-4
# Out:
# CUDA extension for cauchy multiplication not found. Install by going to extensions/cauchy/ and running `python setup.py install`. This should speed up end-to-end training by 10-50%
# Falling back on slow Cauchy kernel. Install at least one of pykeops or the CUDA extension for efficiency.
# Falling back on slow Vandermonde kernel. Install pykeops for improved memory efficiency.
# <class 'model.MySashimi'>
# Selected Device: cuda:0
# wandb: Currently logged in as: emonsarkernsu (499_ratpack). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in /content/apex/wandb/run-20221113_155035-14gq83gq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run experiment_BERT
# wandb: ⭐️ View project at https://wandb.ai/499_ratpack/S4_ActionBERT
# wandb: 🚀 View run at https://wandb.ai/499_ratpack/S4_ActionBERT/runs/14gq83gq
# Training Log Directory: ./results_log/BERT/res18_1fps_lyr_2_bs_256_lr_1e4
#
# ...

# %%
#S4 test
! python3 /content/test/main.py --mode test --expt_dir ./results_log  \
--expt_name S4D --model mys4 \
--data_dir /content/test/testFrame/data_res18_fps_1 \
--run_name res18_1fps_lyr_2_bs_256_lr_1e4 \
--num_layers 5 --batch_size 256 --epochs 300 \
--gpu_id 0 --opt_lvl 1  --num_workers 4 --lr 1e-4
# Out:
# CUDA extension for cauchy multiplication not found. Install by going to extensions/cauchy/ and running `python setup.py install`. This should speed up end-to-end training by 10-50%
# Falling back on slow Cauchy kernel. Install at least one of pykeops or the CUDA extension for efficiency.
# Falling back on slow Vandermonde kernel. Install pykeops for improved memory efficiency.
# <class 'model.MySashimi'>
# Selected Device: cuda:0
# wandb: Currently logged in as: emonsarkernsu (499_ratpack). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in /content/apex/wandb/run-20221113_162811-1qo966a0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run experiment_BERT
# wandb: ⭐️ View project at https://wandb.ai/499_ratpack/S4_ActionBERT
# wandb: 🚀 View run at https://wandb.ai/499_ratpack/S4_ActionBERT/runs/1qo966a0
# Training Log Directory: ./results_log/S4D/res18_1fps_lyr_2_bs_256_lr_1e4
#
# ...

# %%
# !zip -r /content/results_log.zip /content/test/results_log

# %%
from google.colab import files
files.download("/content/results_log.zip")
